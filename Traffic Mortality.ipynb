# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"road-accidents.csv",comment="#",sep="|")
dataset
# Out:
#                    state  drvr_fatl_col_bmiles  perc_fatl_speed  \
# 0                Alabama                  18.8               39
# 1                 Alaska                  18.1               41
# 2                Arizona                  18.6               35
# 3               Arkansas                  22.4               18
# 4             California                  12.0               35
# 5               Colorado                  13.6               37
# 6            Connecticut                  10.8               46
# 7               Delaware                  16.2               38
# 8   District of Columbia                   5.9               34
# 9                Florida                  17.9               21
# 10               Georgia                  15.6               19
# 11                Hawaii                  17.5               54
# 12                 Idaho                  15.3               36
# 13              Illinois                  12.8               36
# 14               Indiana                  14.5               25
# 15                  Iowa                  15.7               17
# 16                Kansas                  17.8               27
# 17              Kentucky                  21.4               19
# 18             Louisiana                  20.5               35
# 19                 Maine                  15.1               38
# 20              Maryland                  12.5               34
# 21         Massachusetts                   8.2               23
# 22              Michigan                  14.1               24
# 23             Minnesota                   9.6               23
# 24           Mississippi                  17.6               15
# 25              Missouri                  16.1               43
# 26               Montana                  21.4               39
# 27              Nebraska                  14.9               13
# 28                Nevada                  14.7               37
# 29         New Hampshire                  11.6               35
# 30            New Jersey                  11.2               16
# 31            New Mexico                  18.4               19
# 32              New York                  12.3               32
# 33        North Carolina                  16.8               39
# 34          North Dakota                  23.9               23
# 35                  Ohio                  14.1               28
# 36              Oklahoma                  19.9               32
# 37                Oregon                  12.8               33
# 38          Pennsylvania                  18.2               50
# 39          Rhode Island                  11.1               34
# 40        South Carolina                  23.9               38
# 41          South Dakota                  19.4               31
# 42             Tennessee                  19.5               21
# 43                 Texas                  19.4               40
# 44                  Utah                  11.3               43
# 45               Vermont                  13.6               30
# 46              Virginia                  12.7               19
# 47            Washington                  10.6               42
# 48         West Virginia                  23.8               34
# 49             Wisconsin                  13.8               36
# 50               Wyoming                  17.4               42
#
#     perc_fatl_alcohol  perc_fatl_1st_time
# 0                  30                  80
# 1                  25                  94
# 2                  28                  96
# 3                  26                  95
# 4                  28                  89
# 5                  28                  95
# 6                  36                  82
# 7                  30                  99
# 8                  27                 100
# 9                  29                  94
# 10                 25                  93
# 11                 41                  87
# 12                 29                  98
# 13                 34                  96
# 14                 29                  95
# 15                 25                  87
# 16                 24                  85
# 17                 23                  76
# 18                 33                  98
# 19                 30                  84
# 20                 32                  99
# 21                 35                  80
# 22                 28                  77
# 23                 29                  88
# 24                 31                 100
# 25                 34                  84
# 26                 44                  85
# 27                 35                  90
# 28                 32                  99
# 29                 30                  83
# 30                 28                  78
# 31                 27                  98
# 32                 29                  80
# 33                 31                  81
# 34                 42                  86
# 35                 34                  82
# 36                 29                  94
# 37                 26                  90
# 38                 31                  88
# 39                 38                  79
# 40                 41                  81
# 41                 33                  86
# 42                 29                  81
# 43                 38                  87
# 44                 16                  96
# 45                 30                  95
# 46                 27                  88
# 47                 33                  86
# 48                 28                  87
# 49                 33                  84
# 50                 32                  90

# %%
dataset.isnull().any()
# Out:
# state                   False
# drvr_fatl_col_bmiles    False
# perc_fatl_speed         False
# perc_fatl_alcohol       False
# perc_fatl_1st_time      False
# dtype: bool

# %%
dataset.corr()
# Out:
#                       drvr_fatl_col_bmiles  perc_fatl_speed  \
# drvr_fatl_col_bmiles              1.000000        -0.029080
# perc_fatl_speed                  -0.029080         1.000000
# perc_fatl_alcohol                 0.199426         0.286244
# perc_fatl_1st_time               -0.017942         0.014066
#
#                       perc_fatl_alcohol  perc_fatl_1st_time
# drvr_fatl_col_bmiles           0.199426           -0.017942
# perc_fatl_speed                0.286244            0.014066
# perc_fatl_alcohol              1.000000           -0.245455
# perc_fatl_1st_time            -0.245455            1.000000

# %%
x=dataset.iloc[:,2:5].values
x
# Out:
# array([[ 39,  30,  80],
#        [ 41,  25,  94],
#        [ 35,  28,  96],
#        [ 18,  26,  95],
#        [ 35,  28,  89],
#        [ 37,  28,  95],
#        [ 46,  36,  82],
#        [ 38,  30,  99],
#        [ 34,  27, 100],
#        [ 21,  29,  94],
#        [ 19,  25,  93],
#        [ 54,  41,  87],
#        [ 36,  29,  98],
#        [ 36,  34,  96],
#        [ 25,  29,  95],
#        [ 17,  25,  87],
#        [ 27,  24,  85],
#        [ 19,  23,  76],
#        [ 35,  33,  98],
#        [ 38,  30,  84],
#        [ 34,  32,  99],
#        [ 23,  35,  80],
#        [ 24,  28,  77],
#        [ 23,  29,  88],
#        [ 15,  31, 100],
#        [ 43,  34,  84],
#        [ 39,  44,  85],
#        [ 13,  35,  90],
#        [ 37,  32,  99],
#        [ 35,  30,  83],
#        [ 16,  28,  78],
#        [ 19,  27,  98],
#        [ 32,  29,  80],
#        [ 39,  31,  81],
#        [ 23,  42,  86],
#        [ 28,  34,  82],
#        [ 32,  29,  94],
#        [ 33,  26,  90],
#        [ 50,  31,  88],
#        [ 34,  38,  79],
#        [ 38,  41,  81],
#        [ 31,  33,  86],
#        [ 21,  29,  81],
#        [ 40,  38,  87],
#        [ 43,  16,  96],
#        [ 30,  30,  95],
#        [ 19,  27,  88],
#        [ 42,  33,  86],
#        [ 34,  28,  87],
#        [ 36,  33,  84],
#        [ 42,  32,  90]], dtype=int64)

# %%
y=dataset.iloc[:,1].values
y
# Out:
# array([18.8, 18.1, 18.6, 22.4, 12. , 13.6, 10.8, 16.2,  5.9, 17.9, 15.6,
#        17.5, 15.3, 12.8, 14.5, 15.7, 17.8, 21.4, 20.5, 15.1, 12.5,  8.2,
#        14.1,  9.6, 17.6, 16.1, 21.4, 14.9, 14.7, 11.6, 11.2, 18.4, 12.3,
#        16.8, 23.9, 14.1, 19.9, 12.8, 18.2, 11.1, 23.9, 19.4, 19.5, 19.4,
#        11.3, 13.6, 12.7, 10.6, 23.8, 13.8, 17.4])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
y_train
# Out:
# array([19.4, 14.9, 14.1, 23.9, 16.2, 14.5, 12.7, 20.5, 23.8, 19.5, 15.7,
#        18.4, 11.2, 17.8, 19.4, 12.5, 17.4,  5.9, 12.8, 16.1, 13.6, 21.4,
#        12.8, 23.9, 18.1, 15.3, 18.2, 17.6, 10.8,  9.6, 19.9,  8.2, 15.1,
#        17.9, 11.1, 13.8, 22.4, 18.8, 10.6, 11.3])

# %%
y_test
# Out:
# array([11.6, 17.5, 15.6, 14.1, 18.6, 14.7, 13.6, 12.3, 21.4, 12. , 16.8])

# %%
x_train
# Out:
# array([[ 31,  33,  86],
#        [ 13,  35,  90],
#        [ 28,  34,  82],
#        [ 23,  42,  86],
#        [ 38,  30,  99],
#        [ 25,  29,  95],
#        [ 19,  27,  88],
#        [ 35,  33,  98],
#        [ 34,  28,  87],
#        [ 21,  29,  81],
#        [ 17,  25,  87],
#        [ 19,  27,  98],
#        [ 16,  28,  78],
#        [ 27,  24,  85],
#        [ 40,  38,  87],
#        [ 34,  32,  99],
#        [ 42,  32,  90],
#        [ 34,  27, 100],
#        [ 36,  34,  96],
#        [ 43,  34,  84],
#        [ 37,  28,  95],
#        [ 19,  23,  76],
#        [ 33,  26,  90],
#        [ 38,  41,  81],
#        [ 41,  25,  94],
#        [ 36,  29,  98],
#        [ 50,  31,  88],
#        [ 15,  31, 100],
#        [ 46,  36,  82],
#        [ 23,  29,  88],
#        [ 32,  29,  94],
#        [ 23,  35,  80],
#        [ 38,  30,  84],
#        [ 21,  29,  94],
#        [ 34,  38,  79],
#        [ 36,  33,  84],
#        [ 18,  26,  95],
#        [ 39,  30,  80],
#        [ 42,  33,  86],
#        [ 43,  16,  96]], dtype=int64)

# %%
x_test
# Out:
# array([[35, 30, 83],
#        [54, 41, 87],
#        [19, 25, 93],
#        [24, 28, 77],
#        [35, 28, 96],
#        [37, 32, 99],
#        [30, 30, 95],
#        [32, 29, 80],
#        [39, 44, 85],
#        [35, 28, 89],
#        [39, 31, 81]], dtype=int64)

# %%
plt.plot(x_train[:,0],y_train)
plt.plot(x_train[:,1],y_train)
plt.plot(x_train[:,2],y_train)
plt.xlabel("causes")
plt.ylabel("accidents")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=mlr.predict(x_test)
y_pred
# Out:
# array([15.73925232, 16.12193976, 15.80236078, 16.05287496, 15.40292435,
#        15.75123639, 15.86813342, 15.78319857, 17.16238394, 15.45941962,
#        15.6905138 ])

# %%
y_pred1=mlr.predict([[34,45,42]])
y_pred1
# Out:
# array([17.85086055])
